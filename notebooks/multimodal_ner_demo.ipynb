# %% [markdown]
# # Multimodal Named Entity Recognition Demo
#
# This notebook demonstrates the capabilities of our multimodal NER system that combines text and visual information for enhanced entity recognition.

# %%
# Import required libraries
import torch
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

from src.models.multimodal_ner import MultimodalNERModel, TextNERModel
from src.data.loaders import MultimodalNERDataset
from src.eval.metrics import MultimodalNEREvaluator
from src.viz.visualization import NERVisualizer, ImageVisualizer
from src.utils.device import setup_device, set_seed
from transformers import AutoTokenizer

# Setup
device = setup_device()
set_seed(42, True)
print(f"Using device: {device}")
